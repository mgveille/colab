# %% [markdown]
# <a href="https://colab.research.google.com/github/mgveille/colab/blob/main/q_panda_yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

# %%
import pandas as pd
import yfinance as yf
df = yf.download('ARAMI.PA' , '2023-08-01', '2023-08-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.head()
# Out:
#              Open  High   Low  Close  Adj Close  Volume
# Date
# 2023-08-01  4.780  4.78  4.43  4.455      4.455  152679
# 2023-08-02  4.620  4.62  4.20  4.305      4.305  144795
# 2023-08-03  4.305  4.43  4.25  4.385      4.385   46777
# 2023-08-04  4.310  4.31  4.22  4.280      4.280   26951
# 2023-08-08  4.065  4.14  4.04  4.080      4.080   36055
